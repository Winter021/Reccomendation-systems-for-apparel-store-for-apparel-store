# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
transactions = pd.read_csv("data/transactions_train.csv")
customers = pd.read_csv("data/customers.csv")
articles = pd.read_csv("data/articles.csv")

# %%
articles.isnull().any()
missing_count = articles['detail_desc'].isnull().sum()
print(missing_count)
# Out:
# 416

# %%
# Removing missing data

articles = articles.dropna(subset=['detail_desc'])
articles = articles.reset_index(drop=True)
articles.shape
# Out:
# (105126, 25)

# %%
articles['product_group_name'].value_counts()
# Out:
# product_group_name
# Garment Upper body       42593
# Garment Lower body       19763
# Garment Full body        13245
# Accessories              11141
# Underwear                 5449
# Shoes                     5196
# Swimwear                  3104
# Socks & Tights            2438
# Nightwear                 1899
# Unknown                    121
# Underwear/nightwear         54
# Cosmetic                    49
# Bags                        25
# Items                       17
# Furniture                   13
# Garment and Shoe care        9
# Stationery                   5
# Interior textile             3
# Fun                          2
# Name: count, dtype: int64

# %%
# Preparation for TF-IDF matrix

articles_str = articles.select_dtypes(include=['object'])
articles_str
# Out:
#                      prod_name product_type_name  product_group_name  \
# 0                    Strap top          Vest top  Garment Upper body
# 1                    Strap top          Vest top  Garment Upper body
# 2                Strap top (1)          Vest top  Garment Upper body
# 3            OP T-shirt (Idro)               Bra           Underwear
# 4            OP T-shirt (Idro)               Bra           Underwear
# ...                        ...               ...                 ...
# 105121  5pk regular Placement1             Socks      Socks & Tights
# 105122       SPORT Malaga tank          Vest top  Garment Upper body
# 105123         Cartwheel dress             Dress   Garment Full body
# 105124        CLAIRE HAIR CLAW         Hair clip         Accessories
# 105125            Lounge dress             Dress   Garment Full body
#
#        graphical_appearance_name colour_group_name  \
# 0                          Solid             Black
# 1                          Solid             White
# 2                         Stripe         Off White
# 3                          Solid             Black
# 4                          Solid             White
# ...                          ...               ...
# 105121           Placement print             Black
# 105122                     Solid             Black
# 105123                     Solid             Black
# 105124                     Solid             Black
# 105125                     Solid         Off White
#
#        perceived_colour_value_name perceived_colour_master_name  \
# 0                             Dark                        Black
# 1                            Light                        White
# 2                      Dusty Light                        White
# 3                             Dark                        Black
# 4                            Light                        White
# ...                            ...                          ...
# 105121                        Dark                        Black
# 105122                        Dark                        Black
# 105123                        Dark                        Black
# 105124                        Dark                        Black
# 105125                 Dusty Light                        White
#
#           department_name index_code        index_name index_group_name  \
# 0            Jersey Basic          A        Ladieswear       Ladieswear
# 1            Jersey Basic          A        Ladieswear       Ladieswear
# 2            Jersey Basic          A        Ladieswear       Ladieswear
# 3          Clean Lingerie          B  Lingeries/Tights       Ladieswear
# 4          Clean Lingerie          B  Lingeries/Tights       Ladieswear
# ...                   ...        ...               ...              ...
# 105121          Socks Bin          F          Menswear         Menswear
# 105122             Jersey          A        Ladieswear       Ladieswear
# 105123             Jersey          A        Ladieswear       Ladieswear
# 105124  Small Accessories          D           Divided          Divided
# 105125             Jersey          A        Ladieswear       Ladieswear
#
#                   section_name garment_group_name  \
# 0       Womens Everyday Basics       Jersey Basic
# 1       Womens Everyday Basics       Jersey Basic
# 2       Womens Everyday Basics       Jersey Basic
# 3              Womens Lingerie  Under-, Nightwear
# 4              Womens Lingerie  Under-, Nightwear
# ...                        ...                ...
# 105121           Men Underwear   Socks and Tights
# 105122                    H&M+       Jersey Fancy
# 105123            Womens Trend       Jersey Fancy
# 105124     Divided Accessories        Accessories
# 105125            Womens Trend       Jersey Fancy
#
#                                               detail_desc
# 0                 Jersey top with narrow shoulder straps.
# 1                 Jersey top with narrow shoulder straps.
# 2                 Jersey top with narrow shoulder straps.
# 3       Microfibre T-shirt bra with underwired, moulde...
# 4       Microfibre T-shirt bra with underwired, moulde...
# ...                                                   ...
# 105121  Socks in a fine-knit cotton blend with a small...
# 105122  Loose-fitting sports vest top in ribbed fast-d...
# 105123  Short, A-line dress in jersey with a round nec...
# 105124                           Large plastic hair claw.
# 105125  Calf-length dress in ribbed jersey made from a...
#
# [105126 rows x 14 columns]

# %%
# Concatenate all text columns to create a document collection

documents = articles_str.apply(' '.join, axis=1)
print(documents)
# Out:
# 0         Strap top Vest top Garment Upper body Solid Bl...
# 1         Strap top Vest top Garment Upper body Solid Wh...
# 2         Strap top (1) Vest top Garment Upper body Stri...
# 3         OP T-shirt (Idro) Bra Underwear Solid Black Da...
# 4         OP T-shirt (Idro) Bra Underwear Solid White Li...
#                                 ...
# 105121    5pk regular Placement1 Socks Socks & Tights Pl...
# 105122    SPORT Malaga tank Vest top Garment Upper body ...
# 105123    Cartwheel dress Dress Garment Full body Solid ...
# 105124    CLAIRE HAIR CLAW Hair clip Accessories Solid B...
# 105125    Lounge dress Dress Garment Full body Solid Off...
# Length: 105126, dtype: object

# %%
import re
from tqdm import tqdm
from nltk.corpus import stopwords

def preprocess_text_with_progress(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    tokens = text.split()
    filtered_tokens = [word for word in tokens if word not in stopwords.words('english')]
    return " ".join(filtered_tokens)

# Apply preprocess_text_with_progress to each document
documents_processed = []

# Use tqdm to track the progress
for document in tqdm(documents):
    documents_processed.append(preprocess_text_with_progress(document))

print(documents_processed)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 105126/105126 [19:31<00:00, 89.77it/s]
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
print(documents_processed[0])
# Out:
# strap top vest top garment upper body solid black dark black jersey basic ladieswear ladieswear womens everyday basics jersey basic jersey top narrow shoulder straps

# %%
# TF-IDF vectorization

tfidf = TfidfVectorizer()

# %%
# Convert the document collection to TF-IDF vectors

tfidf_matrix = tfidf.fit_transform(documents_processed)
# print(tfidf_matrix.toarray())

# %%
# Examining the TF-IDF matrix

tfidf_matrix.shape
tfidf.get_feature_names_out()
# Out:
# array(['0241590', '0241602', '0391750', ..., 'öppen', 'örhängen', 'ﬁbres'],
#       dtype=object)

# %%
def most_similar_tfidf_vectors(tfidf_matrix, tfidf_vector, n=6):
    # Compute cosine similarity between tfidf_vector and all vectors in tfidf_matrix
    similarities = cosine_similarity(tfidf_matrix, tfidf_vector.reshape(1, -1))
    
    # Flatten similarities array and get indexes of top n most similar vectors
    similar_indexes = np.argsort(similarities.flatten())[::-1][:n]
    
    similar_article_ids = articles.iloc[similar_indexes]
    
    return similar_article_ids

# %%
import random

# %%
# The code snippet that generates recommendations for a random article using your content-based recommender
id = random.randint(0,tfidf_matrix.shape[0]-1)
tfidf_vector = tfidf_matrix[id].toarray()
print(articles[['article_id', 'prod_name', 'product_type_name']].iloc[id])
recommended_articles = most_similar_tfidf_vectors(tfidf_matrix, tfidf_vector, 6)

recommended_articles[['article_id','prod_name','product_type_name','product_group_name','department_name','index_name','detail_desc']]
# Out:
# article_id                            584200005
# prod_name            Bianca off shoulder blouse
# product_type_name                        Blouse
# Name: 19282, dtype: object
#        article_id                   prod_name product_type_name  \
# 19282   584200005  Bianca off shoulder blouse            Blouse
# 19283   584200006  Bianca off shoulder blouse            Blouse
# 93610   860646001            VIOLET LS BLOUSE            Blouse
# 55871   713699004          MOLLY OFF SHOULDER            Blouse
# 55870   713699002          MOLLY OFF SHOULDER            Blouse
# 55872   713699005          MOLLY OFF SHOULDER            Blouse
#
#        product_group_name department_name index_name  \
# 19282  Garment Upper body      Tops Woven    Divided
# 19283  Garment Upper body      Tops Woven    Divided
# 93610  Garment Upper body      Tops Woven    Divided
# 55871  Garment Upper body      Tops Woven    Divided
# 55870  Garment Upper body      Tops Woven    Divided
# 55872  Garment Upper body      Tops Woven    Divided
#
#                                              detail_desc
# 19282  Off-the-shoulder blouse in a cotton weave with...
# 19283  Off-the-shoulder blouse in a cotton weave with...
# 93610  Cold shoulder blouse in a crêpe weave with nar...
# 55871  Short, off-the-shoulder blouse in a crêpe weav...
# 55870  Short, off-the-shoulder blouse in a crêpe weav...
# 55872  Short, off-the-shoulder blouse in a crêpe weav...
